# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\Jupyter Notebook\DSDBA\iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print("The mean of sepal_length is :",df.loc[:,"sepal_length"].mean()) 
print("The mean of sepal_width is :",df.loc[:,"sepal_width"].mean())
print("The mean of petal_length is :",df.loc[:,"petal_length"].mean())
print("The mean of petal_width is :",df.loc[:,"petal_width"].mean())
# Out:
# The mean of sepal_length is : 5.843333333333334
# The mean of sepal_width is : 3.0540000000000003
# The mean of petal_length is : 3.758666666666666
# The mean of petal_width is : 1.1986666666666668

# %%
print("The median of sepal_length is :",df.loc[:,"sepal_length"].median()) 
print("The median of sepal_width is :",df.loc[:,"sepal_width"].median()) 
print("The median of petal_length is :",df.loc[:,"petal_length"].median()) 
print("The median of petal_width is :",df.loc[:,"petal_width"].median())
# Out:
# The median of sepal_length is : 5.8
# The median of sepal_width is : 3.0
# The median of petal_length is : 4.35
# The median of petal_width is : 1.3

# %%
print("The mode of sepal_length is :",df.loc[:,"sepal_length"].mode()) 
print("The mode of sepal_width is :",df.loc[:,"sepal_width"].mode()) 
print("The mode of petal_length is :",df.loc[:,"petal_length"].mode()) 
print("The mode of petal_width is :",df.loc[:,"petal_width"].mode())
# Out:
# The mode of sepal_length is : 0    5.0
# Name: sepal_length, dtype: float64
# The mode of sepal_width is : 0    3.0
# Name: sepal_width, dtype: float64
# The mode of petal_length is : 0    1.5
# Name: petal_length, dtype: float64
# The mode of petal_width is : 0    0.2
# Name: petal_width, dtype: float64

# %%
print("The standard deviation of sepal_length is :",df.loc[:,"sepal_length"].std()) 
print("The standard deviation of sepal_width is :",df.loc[:,"sepal_width"].std())
print("The standard deviation of petal_length is :",df.loc[:,"petal_length"].std()) 
print("The standard deviation of petal_width is :",df.loc[:,"petal_width"].std())
# Out:
# The standard deviation of sepal_length is : 0.828066127977863
# The standard deviation of sepal_width is : 0.4335943113621737
# The standard deviation of petal_length is : 1.7644204199522626
# The standard deviation of petal_width is : 0.7631607417008411

# %%
array1 = np.array(df['sepal_length']) 
array2=np.array(df["sepal_width"]) 
print("length",array1) 
print("width",array2)
# Out:
# length [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#  6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#  5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#  6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#  6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#  6.7 6.7 6.3 6.5 6.2 5.9]
# width [3.5 3.  3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.  3.  4.  4.4 3.9 3.5
#  3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.  3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#  3.5 3.1 3.  3.4 3.5 2.3 3.2 3.5 3.8 3.  3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#  2.8 2.8 3.3 2.4 2.9 2.7 2.  3.  2.2 2.9 2.9 3.1 3.  2.7 2.2 2.5 3.2 2.8
#  2.5 2.8 2.9 3.  2.8 3.  2.9 2.6 2.4 2.4 2.7 2.7 3.  3.4 3.1 2.3 3.  2.5
#  2.6 3.  2.6 2.3 2.7 3.  2.9 2.9 2.5 2.8 3.3 2.7 3.  2.9 3.  3.  2.5 2.9
#  2.5 3.6 3.2 2.7 3.  2.5 2.8 3.2 3.  3.8 2.6 2.2 3.2 2.8 2.8 2.7 3.3 3.2
#  2.8 3.  2.8 3.  2.8 3.8 2.8 2.8 2.6 3.  3.4 3.1 3.  3.1 3.1 3.1 2.7 3.2
#  3.3 3.  2.5 3.  3.4 3. ]

# %%
print("Maximum length among the sepal_length is :",max(array1)) 
print("Minimum length among the sepal_length is :",min(array1)) 
print("Maximum width among the sepal_width is :",max(array2)) 
print("Minimum width among the sepal_width is :",min(array2))
# Out:
# Maximum length among the sepal_length is : 7.9
# Minimum length among the sepal_length is : 4.3
# Maximum width among the sepal_width is : 4.4
# Minimum width among the sepal_width is : 2.0

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sorted_rscore= sorted(df['sepal_length'])
sorted_rscore
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 5.1 6.4

# %%
IQR = q3-q1
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 3.1499999999999986 8.350000000000001

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset = sns.load_dataset('iris')
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# sns.distplot(x = dataset['petal_width'], bins = 10)
import seaborn as sns
sns.histplot(x = dataset['petal_width'], bins = 10,kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.distplot(dataset['petal_length'], bins = 10,kde=False)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13552\1137408225.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['petal_length'], bins = 10,kde=False)
# <Axes: xlabel='petal_length'>

# %%
sns.jointplot(x = dataset['petal_length'], y = dataset['sepal_length'], kind ='scatter')

# %%
sns.jointplot(x =  dataset['petal_length'], y = dataset['sepal_length'], kind = 'hex')

# %%
sns.rugplot(dataset['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length'>

# %%
sns.barplot(x='species', y='sepal_length', data=dataset)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(x='species', y='sepal_length', data=dataset, estimator=np.std)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.countplot(x='species', data=dataset)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.boxplot(x='species', y='sepal_length', data=dataset)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(x='species', y='sepal_length', data=dataset, hue="species")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(x='species', y='sepal_length', data=dataset)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(x='species', y='sepal_length', data=dataset, hue="species")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.stripplot(x='species', y='sepal_length', data=dataset, jitter=False)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.stripplot(x='species', y='sepal_length', data=dataset, jitter=True)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.stripplot(x='species', y='sepal_length', data=dataset, jitter=True, hue='species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.swarmplot(x='species', y='sepal_length', data=dataset)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.swarmplot(x='species', y='sepal_length', data=dataset, hue='species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.pairplot(dataset,hue="species",height=2.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset = sns.load_dataset('iris')
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import pandas as pd
numeric_columns = dataset.select_dtypes(include=[np.number])
correlation_matrix = numeric_columns.corr()
print(correlation_matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
corr = dataset.select_dtypes(include=['number']).corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.show()

# %%
corr = dataset.select_dtypes(include=['number']).corr()

# Plot heatmap with annotations
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)

# Show the plot
plt.show()
